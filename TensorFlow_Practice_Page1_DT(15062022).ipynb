# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahin5378/TensorFlow/blob/main/TensorFlow_Practice_Page1_DT(15062022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Creating Environment for TensorFlow**

# %% [markdown]
# ##Imports

# %%
# import tensorflow as tf

# %%
# import numpy as np

# %%
# from tensorflow import keras

# %%
# print (tf.__version__)
# Out:
# 2.8.2

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
print (tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# ##**Define and Compile Nural Network**

# %%
# Build a simple sequential model
model = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])

# %%
# compile the model (Compile the Nural Network Identify the Loss function)
model.compile(optimizer='sgd', loss = 'mean_squared_error')

# %% [markdown]
# ##Providing Data

# %%
# Declare model inputs and outputs for training
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype = float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype = float)

# %% [markdown]
# ##Training the Nural Network

# %%
# Train the model
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 484ms/step - loss: 0.5651
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5517
# Epoch 3/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5389
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5267
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5150
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5037
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4928
# Epoch 8/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4823
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4720
# Epoch 10/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4621
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4524
# Epoch 12/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4429
# ...

# %%
# Make a prediction
print(model.predict([10.0]))
# Out:
# [[18.98774]]
